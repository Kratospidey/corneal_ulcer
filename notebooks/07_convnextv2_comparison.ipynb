# %% [markdown]
# # ConvNeXtV2 Comparison
#
# This notebook reads the final Phase 4 rollup reports and compares ConvNeXtV2 against the official Stage 3 AlexNet raw baseline.

# %%
from pathlib import Path

report_path = Path('outputs/reports/convnextv2_vs_baseline_summary.md')
print(report_path.read_text() if report_path.exists() else 'ConvNeXtV2 comparison report not generated yet.')
