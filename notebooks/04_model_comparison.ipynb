# %% [markdown]
# # Baseline Preprocessing Comparison
#
# Compare raw RGB against `masked_highlight_proxy` on the same duplicate-aware holdout split.

# %%
import pandas as pd

raw_metrics = pd.read_json('outputs/metrics/pattern3_resnet18_raw/test_metrics.json', typ='series') if False else None

# %%
# !python src/main_train.py --config configs/train_resnet18_paper.yaml
