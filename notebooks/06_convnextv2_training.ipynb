# %% [markdown]
# # ConvNeXtV2 Training
#
# Phase 4 runs on the duplicate-aware holdout split created in Stage 3. The first run is `convnextv2_tiny` on raw RGB.

# %%
from pathlib import Path
import json

metrics_path = Path('outputs/metrics/pattern3__convnextv2_tiny__raw_rgb__holdout_v1__seed42/test_metrics.json')
json.loads(metrics_path.read_text()) if metrics_path.exists() else {'status': 'run pending'}
