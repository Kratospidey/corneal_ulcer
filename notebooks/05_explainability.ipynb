# %% [markdown]
# # Baseline Explainability
#
# Generate Grad-CAM overlays for correct, incorrect, and borderline test predictions.

# %%
# !python src/explainability/explain.py --config configs/explainability.yaml --checkpoint models/checkpoints/pattern3_resnet18_raw/best.pt
