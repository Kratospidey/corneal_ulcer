# %% [markdown]
# # Stage 3 Baseline Models
#
# This notebook reviews the leakage-aware 3-class baseline benchmark built from the Stage 2 manifest and duplicate checks.

# %%
from pathlib import Path
import pandas as pd

manifest = pd.read_csv('data/interim/manifests/manifest.csv')
manifest.head()

# %%
# !python src/main_train.py --config configs/train_resnet18_raw.yaml
