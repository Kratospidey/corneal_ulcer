# %% [markdown]
# # ConvNeXtV2 Explainability
#
# Use this notebook to review Grad-CAM outputs for correct, incorrect, and borderline ConvNeXtV2 test cases.

# %%
from pathlib import Path

base = Path('outputs/explainability/pattern3__convnextv2_tiny__raw_rgb__holdout_v1__seed42')
sorted(str(path) for path in base.rglob('*.png'))[:12] if base.exists() else ['Explainability outputs not generated yet.']
